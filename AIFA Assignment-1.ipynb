# %%
def all_pairs_shortest_path (arr): ## arr -> Adjacency Matrix
    
    apst = [[9999 for i in range(len(arr[0]))]for j in range(len(arr))]
    for i in ranage(len(arr)):
        for j in range(len(arr[0])):
            apst[i][j] = arr[i][j]
            if i==j:
                apst[i][j]=0
            apst[j][i] = apst[i][j]
            
    for k in range(len(arr)):
        for i in range(len(arr)):
            for j in range(len(arr)):
                apst[i][j] = min(apst[i][j],apst[i][k]+apst[k][j])
    return apst

def min_time (ev, apst, arr, visited, dist): ##arr -> Adjacency List  ##Dist -> Distance Matrix 
    
    visited[ev[0]]=1
    from collections import deque
    q=deque()
    q.append(ev[0])
    k=None
    while 1:
        k=q.popleft()
        if k==ev[1]:
            break

# %%
print ('Enter the Number of EVs')
k=int(input())
ev=[]
for _ in range(k):
    a=list(map(int,input().split()))
    ev.append(tuple(a))

# %%
a=[1,2,3]
a=tuple(a)
a
# Out:
# (1, 2, 3)
